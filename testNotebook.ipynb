# %%
from polarization_model.classes.model import PolarizationModel
from polarization_model.classes.visualizer import Visualizer

# %%
model = PolarizationModel()
nAgents      = 1000
targetDegree = 2
opinionMean  = 0
opinionStDev = 1
minConf      = 0
maxConf      = 0.5
minTol       = 0
maxTol       = 0.5

model.generateAgents(nAgents, opinionMean, opinionStDev, minConf, maxConf, minTol, maxTol)
model.lockDegree(targetDegree)
vis = Visualizer(model)
vis.run(100, 10)
